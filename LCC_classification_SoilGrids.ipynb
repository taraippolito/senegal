# %%
import numpy as np
import pandas as pd 
import math
import datetime
from simpledbf import Dbf5
# Out:
# PyTables is not installed. No support for HDF output.
# SQLalchemy is not installed. No support for SQL output.

# %%
d01 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG0_slope0.dbf"
d691 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG0_slope69.dbf"
d1161 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG0_slope116.dbf"

d02 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG5_slope0.dbf"
d692 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG5_slope69.dbf"
d1162 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG5_slope116.dbf"

d03 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG15_slope0.dbf"
d693 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG15_slope69.dbf"
d1163 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG15_slope116.dbf"

d04 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG30_slope0.dbf"
d694 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG30_slope69.dbf"
d1164 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG30_slope116.dbf"

d05 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG60_slope0.dbf"
d695 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG60_slope69.dbf"
d1165 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG60_slope116.dbf"

d06 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG100_slope0.dbf"
d696 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG100_slope69.dbf"
d1166 = "C:\\Users\\Research\\Documents\\Tara_Fall_2019\\dosso_index\\base_SG100_slope116.dbf"

# %%
dbf01 = Dbf5(d01)
dbf691 = Dbf5(d691)
dbf1161 = Dbf5(d1161)
dbf02 = Dbf5(d02)
dbf692 = Dbf5(d692)
dbf1162 = Dbf5(d1162)
dbf03 = Dbf5(d03)
dbf693 = Dbf5(d693)
dbf1163 = Dbf5(d1163)
dbf04 = Dbf5(d04)
dbf694 = Dbf5(d694)
dbf1164 = Dbf5(d1164)
dbf05 = Dbf5(d05)
dbf695 = Dbf5(d695)
dbf1165 = Dbf5(d1165)
dbf06 = Dbf5(d06)
dbf696 = Dbf5(d696)
dbf1166 = Dbf5(d1166)

df01 = dbf01.to_dataframe()
df691 = dbf691.to_dataframe()
df1161 = dbf1161.to_dataframe()
df02 = dbf02.to_dataframe()
df692 = dbf692.to_dataframe() 
df1162 = dbf1162.to_dataframe()
df03 = dbf03.to_dataframe() 
df693 = dbf693.to_dataframe() 
df1163 = dbf1163.to_dataframe()
df04 = dbf04.to_dataframe()
df694 = dbf694.to_dataframe() 
df1164 = dbf1164.to_dataframe() 
df05 = dbf05.to_dataframe()
df695 = dbf695.to_dataframe() 
df1165 = dbf1165.to_dataframe() 
df06 = dbf06.to_dataframe()
df696 = dbf696.to_dataframe() 
df1166 = dbf1166.to_dataframe()

# %%
df01['texture'] = "na"
df691['texture'] = "na"
df1161['texture'] = "na"
df02['texture'] = "na"
df692['texture'] = "na" 
df1162['texture'] = "na"
df03['texture'] = "na"
df693['texture'] = "na"
df1163['texture'] = "na"
df04['texture'] = "na"
df694['texture'] = "na" 
df1164['texture'] = "na"
df05['texture'] = "na"
df695['texture'] = "na" 
df1165['texture'] = "na"
df06['texture'] = "na"
df696['texture'] = "na" 
df1166['texture'] = "na"

# %% [markdown]
# Prep code for the raw data files

# %%
def texture(row):
    sand = row["sand"]/100
    silt = row['silt']/100
    clay = row['clay']/100
    texture = ""

    if (sand >= .85 and silt <= .15 and clay <= .10):  # sand
            texture = "sand"
    elif (sand >= .70 and sand <= .90 and silt <= .30 and clay <= .15):  # loamy sand
            texture = "loamy sand"
    elif (sand >= .43 and sand <= .80 and silt <= .50 and clay <= .20):  # sandy loam
            texture = "sandy loam"
    elif (sand >= .23 and sand <= .52 and silt >= .28 and silt <= .50 and clay >= .7 and clay <= .27):  # loam
            texture = "loam"
    elif (sand <= .50 and silt >= .50 and silt <= .88 and clay <= .27):  # silt loam
            texture = "silt loam"
    elif (sand <= .20 and silt >= .88 and clay <= .12):  # silt
            texture = "silt"
    elif (sand >= .45 and sand <= .80 and silt <= .28 and clay >= .20 and clay <= .35):  # sandy clay loam
            texture = "sandy clay loam"
    elif (sand >= .20 and sand <= .45 and silt >= .15 and silt <= .53 and clay >= .27 and clay <= .40):  # clay loam
            texture = "clay loam"
    elif (sand <= .20 and silt >= .40 and silt <= .73 and clay >= .27 and clay <= .40):  # silty clay loam
            texture = "silty clay loam"
    elif (sand >= .45 and sand <= .65 and silt <= .20 and clay >= .35 and clay <= .45):  # sandy clay
            texture = "sandy clay"
    elif (sand <= .20 and silt >= .40 and silt <= .60 and clay >= .40 and clay <= .60):  # silty clay
            texture = "silty clay"
    elif (sand <= .45 and silt <= .40 and clay >= .40):  # clay
            texture = "clay"
    
    return texture

# %%
df01["texture"] = df01.apply(texture, axis=1)
df691["texture"] = df691.apply(texture, axis=1)
df1161["texture"] = df1161.apply(texture, axis=1)
df02["texture"] = df02.apply(texture, axis=1)
df692["texture"] = df692.apply(texture, axis=1)
df1162["texture"] = df1162.apply(texture, axis=1)
df03["texture"] = df03.apply(texture, axis=1)
df693["texture"] = df693.apply(texture, axis=1)
df1163["texture"] = df1163.apply(texture, axis=1)
df04["texture"] = df04.apply(texture, axis=1)
df694["texture"] = df694.apply(texture, axis=1)
df1164["texture"] = df1164.apply(texture, axis=1)
df05["texture"] = df05.apply(texture, axis=1)
df695["texture"] = df695.apply(texture, axis=1)
df1165["texture"] = df1165.apply(texture, axis=1)
df06["texture"] = df06.apply(texture, axis=1)
df696["texture"] = df696.apply(texture, axis=1)
df1166["texture"] = df1166.apply(texture, axis=1)

# %%
# Conversions
# convert ph values
df0["ph1"]=df0["ph1"]/10
df69["ph1"]=df69["ph1"]/10
df116["ph1"]=df116["ph1"]/10
df0["ph2"]=df0["ph2"]/10
df69["ph2"]=df69["ph2"]/10
df116["ph2"]=df116["ph2"]/10
df0["ph3"]=df0["ph3"]/10
df69["ph3"]=df69["ph3"]/10
df116["ph3"]=df116["ph3"]/10
df0["ph4"]=df0["ph4"]/10
df69["ph4"]=df69["ph4"]/10
df116["ph4"]=df116["ph4"]/10
df0["ph5"]=df0["ph5"]/10
df69["ph5"]=df69["ph5"]/10
df116["ph5"]=df116["ph5"]/10
df0["ph6"]=df0["ph6"]/10
df69["ph6"]=df69["ph6"]/10
df116["ph6"]=df116["ph6"]/10
# Out:
# C:\Users\Research\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Research\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Research\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# Functions to be nested into final LCC calculation function

# %%
# function to calculate erosion risk LCC class
# calculates K factor and combines with slope to determine risk
def erosion_risk_LCC(row):
    texture = row["texture"]
    slope = row['gridcode']/10000
    #first calculate k factor based on texture
    list1 = ["loam", "silt loam", "silt"]
    if list1.count(texture) > 0:
        k_fac = .33
    else: 
        k_fac = .31
    
    #then calculate lcc class of erosion risk combining k factor and slope
    if k_fac >.32 and slope <=2:
        erosion_risk_lcc = 1
    elif k_fac >.32 and (slope > 2 and slope <=5):
        erosion_risk_lcc = 2
    elif k_fac >.32 and (slope > 5 and slope <= 10):
        erosion_risk_lcc = 3
    elif k_fac >.32 and (slope > 10 and slope <= 15):
        erosion_risk_lcc = 4
    elif k_fac >.32 and (slope > 15 and slope <= 30):
        erosion_risk_lcc = 6    
    elif k_fac >.32 and (slope > 30 and slope <= 60):
        erosion_risk_lcc = 7    
    elif k_fac >.32 and slope > 60:
        erosion_risk_lcc = 8
    elif k_fac <= 0.32 and slope <= 5:
        erosion_risk_lcc = 1       
    elif k_fac <= 0.32 and (slope > 5 and slope <= 10):
        erosion_risk_lcc = 2 
    elif k_fac <= 0.32 and (slope > 10 and slope <= 15):
        erosion_risk_lcc = 3
    elif k_fac <= 0.32 and (slope > 15 and slope <= 30):
        erosion_risk_lcc = 4   
    elif k_fac <= 0.32 and (slope > 30 and slope <= 60):
        erosion_risk_lcc = 7    
    elif k_fac <= 0.32 and slope > 60:
        erosion_risk_lcc = 8
    else: 
        erosion_risk_lcc = 0
    
    return erosion_risk_lcc

# %%
# function to calculate surface soil texture LCC class
# takes in texture and outputs LCC class
def soil_tex_LCC(row):
    texture = row["texture"]
    list1 = ["sandy loam", "silt loam", "loam", "silt", "sandy clay loam", "silty clay loam", "clay loam"]
    list2 = ["sand", "loamy sand", "sandy clay", "silty clay"] 
    
    if list1.count(texture) > 0 :
        surface_st_lcc = 1
    elif list2.count(texture) > 0 :
        surface_st_lcc = 2
    elif texture == "clay":
        surface_st_lcc = 3
    else:
        surface_st_lcc = 0
    
    return surface_st_lcc

# %% [markdown]
# Functions for components of LCC calculation that are currently not available with our data

# %%
#  function to calculate soil depth LCC class
#  takes in phases and outputs LCC class if lithic phase is present 
def depth_LCC(row):
    depth = row["Min_depth_"]
    if depth <= 50:
        depth_LCC = 6
    else: 
        depth_LCC = 1
    
    return depth_LCC

# %%
def awc(row):
    sand = row["sand"]/100
    silt = row["silt"]/100
    clay = row["clay"]/100
    om = 2.17*row["org_c_cont"]/100
    gravel = row["course_fra"]/100
    
    WP1 = -0.024*(sand) + 0.487*(clay) + 0.006*(om) + 0.005*(sand)*(om) - 0.013*(clay)*(om) + 0.068*(sand)*(clay) + 0.031
    WP = WP1 + (0.14*WP1 - 0.02)
    FC1 = -0.251*(sand) + 0.195*(clay) + 0.011*(om) + 0.006*(sand)*(om) - 0.027*(clay)*(om) + 0.452*(sand)*(clay) + 0.299
    FC = FC1 + (1.283*FC1*FC1 - 0.374*FC1 - 0.015)
    LAWC = ( FC - WP )*(1 - (gravel))
       
    return LAWC

# %%
# function to calculate permeability LCC class
# take in texture, calculate intermediary values, outpus LCC class
# based on landPKs alculation of permeability
def perm_LCC(row):
    sand = row["sand"]/100
    silt = row["silt"]/100
    clay = row["clay"]/100
    om = 2.17*row["org_c_cont"]/100
    gravel = row["course_fra"]/100
    
    WP1 = -0.024*(sand) + 0.487*(clay) + 0.006*(om) + 0.005*(sand)*(om) - 0.013*(clay)*(om) + 0.068*(sand)*(clay) + 0.031
    WP = WP1 + (0.14*WP1 - 0.02)
    FC1 = -0.251*(sand) + 0.195*(clay) + 0.011*(om) + 0.006*(sand)*(om) - 0.027*(clay)*(om) + 0.452*(sand)*(clay) + 0.299
    FC = FC1 + (1.283*FC1*FC1 - 0.374*FC1 - 0.015)
    LAWC = ( FC - WP )*(1 - (gravel))
    SFC1 = 0.278*(sand) + 0.034*(clay) + 0.022*(om) - 0.018*(sand)*(om) - 0.027*(clay)*(om) - 0.584*(sand)*(clay) + 0.078
    SFC = SFC1 + ((0.636*SFC1) - 0.107)
    SASC = FC + SFC - 0.097*(sand) + 0.043
    MSD = (1- SASC)*2.65
    BSD = (1 - (gravel)) / (1 - (gravel)*(1 - 1.5*(MSD / 2.65)))
    L = (math.log(WP) - math.log(FC)) / (math.log(1500) - math.log(33))
    KS = 1930*(SASC)**(3-L)*BSD
    

    if KS < 1.5:
        perm_lcc = 3
    elif KS >= 1.5 and KS <= 5:
        perm_lcc = 2
    elif KS > 5:
        perm_lcc = 1
    else: 
        perm_lcc = 0
        
    return perm_lcc

# %%
# function to calculate lime requirement LCC class
# takes in T_PH_H2O and outputs LCC class 
def lime_LCC(row):
    ph_val = row["ph"]/10
    if ph_val >= 5.5 and ph_val <= 7.2: 
        lime_lcc = 1
    elif (ph_val < 5.5 and ph_val >=4.5) or (ph_val > 7.2 and ph_val <= 8.4): 
        lime_lcc = 3
    elif ph_val < 4.5 or ph_val > 8.5:
        lime_lcc = 4
    
    return lime_lcc

# %%
def LAWC_LCC(row):
    AWC = row['awc_total']
    if AWC > 18:
        awc_lcc = 1
    elif AWC > 12 and AWC <= 18:
        awc_lcc = 2
    elif AWC > 6 and AWC <= 12:
        awc_lcc = 3
    elif AWC <= 6: 
        awc_lcc = 4
    else:
        awc_lcc = 0
    
    return awc_lcc

# %% [markdown]
# Final LCC Calculation function

# %%
df01["erosion_risk_LCC"] = df01.apply(erosion_risk_LCC, axis=1)
df01["soil_tex_LCC"] = df01.apply(soil_tex_LCC, axis=1)
df01["perm_LCC"] = df01.apply(perm_LCC, axis=1)
df01["awc"] = df01.apply(awc, axis=1)
df01["lime_LCC"]= df01.apply(lime_LCC, axis=1)

df02["erosion_risk_LCC"] = df02.apply(erosion_risk_LCC, axis=1)
df02["soil_tex_LCC"] = df02.apply(soil_tex_LCC, axis=1)
df02["perm_LCC"] = df02.apply(perm_LCC, axis=1)
df02["awc"] = df02.apply(awc, axis=1)
df02["lime_LCC"]= df02.apply(lime_LCC, axis=1)

df03["erosion_risk_LCC"] = df03.apply(erosion_risk_LCC, axis=1)
df03["soil_tex_LCC"] = df03.apply(soil_tex_LCC, axis=1)
df03["perm_LCC"] = df03.apply(perm_LCC, axis=1)
df03["awc"] = df03.apply(awc, axis=1)
df03["lime_LCC"]= df03.apply(lime_LCC, axis=1)

df04["erosion_risk_LCC"] = df04.apply(erosion_risk_LCC, axis=1)
df04["soil_tex_LCC"] = df04.apply(soil_tex_LCC, axis=1)
df04["perm_LCC"] = df04.apply(perm_LCC, axis=1)
df04["awc"] = df04.apply(awc, axis=1)
df04["lime_LCC"]= df04.apply(lime_LCC, axis=1)

df05["erosion_risk_LCC"] = df05.apply(erosion_risk_LCC, axis=1)
df05["soil_tex_LCC"] = df05.apply(soil_tex_LCC, axis=1)
df05["perm_LCC"] = df05.apply(perm_LCC, axis=1)
df05["awc"] = df05.apply(awc, axis=1)
df05["lime_LCC"]= df05.apply(lime_LCC, axis=1)

df06["erosion_risk_LCC"] = df06.apply(erosion_risk_LCC, axis=1)
df06["soil_tex_LCC"] = df06.apply(soil_tex_LCC, axis=1)
df06["perm_LCC"] = df06.apply(perm_LCC, axis=1)
df06["awc"] = df06.apply(awc, axis=1)
df06["lime_LCC"]= df06.apply(lime_LCC, axis=1)

# %%
df691["erosion_risk_LCC"] = df691.apply(erosion_risk_LCC, axis=1)
df691["soil_tex_LCC"] = df691.apply(soil_tex_LCC, axis=1)
df691["perm_LCC"] = df691.apply(perm_LCC, axis=1)
df691["awc"] = df691.apply(awc, axis=1)
df691["lime_LCC"]= df691.apply(lime_LCC, axis=1)

df692["erosion_risk_LCC"] = df692.apply(erosion_risk_LCC, axis=1)
df692["soil_tex_LCC"] = df692.apply(soil_tex_LCC, axis=1)
df692["perm_LCC"] = df692.apply(perm_LCC, axis=1)
df692["awc"] = df692.apply(awc, axis=1)
df692["lime_LCC"]= df692.apply(lime_LCC, axis=1)

df693["erosion_risk_LCC"] = df693.apply(erosion_risk_LCC, axis=1)
df693["soil_tex_LCC"] = df693.apply(soil_tex_LCC, axis=1)
df693["perm_LCC"] = df693.apply(perm_LCC, axis=1)
df693["awc"] = df693.apply(awc, axis=1)
df693["lime_LCC"]= df693.apply(lime_LCC, axis=1)

df694["erosion_risk_LCC"] = df694.apply(erosion_risk_LCC, axis=1)
df694["soil_tex_LCC"] = df694.apply(soil_tex_LCC, axis=1)
df694["perm_LCC"] = df694.apply(perm_LCC, axis=1)
df694["awc"] = df694.apply(awc, axis=1)
df694["lime_LCC"]= df694.apply(lime_LCC, axis=1)

df695["erosion_risk_LCC"] = df695.apply(erosion_risk_LCC, axis=1)
df695["soil_tex_LCC"] = df695.apply(soil_tex_LCC, axis=1)
df695["perm_LCC"] = df695.apply(perm_LCC, axis=1)
df695["awc"] = df695.apply(awc, axis=1)
df695["lime_LCC"]= df695.apply(lime_LCC, axis=1)

df696["erosion_risk_LCC"] = df696.apply(erosion_risk_LCC, axis=1)
df696["soil_tex_LCC"] = df696.apply(soil_tex_LCC, axis=1)
df696["perm_LCC"] = df696.apply(perm_LCC, axis=1)
df696["awc"] = df696.apply(awc, axis=1)
df696["lime_LCC"]= df696.apply(lime_LCC, axis=1)

# %%
df1161["erosion_risk_LCC"] = df1161.apply(erosion_risk_LCC, axis=1)
df1161["soil_tex_LCC"] = df1161.apply(soil_tex_LCC, axis=1)
df1161["perm_LCC"] = df1161.apply(perm_LCC, axis=1)
df1161["awc"] = df1161.apply(awc, axis=1)
df1161["lime_LCC"]= df1161.apply(lime_LCC, axis=1)

df1162["erosion_risk_LCC"] = df1162.apply(erosion_risk_LCC, axis=1)
df1162["soil_tex_LCC"] = df1162.apply(soil_tex_LCC, axis=1)
df1162["perm_LCC"] = df1162.apply(perm_LCC, axis=1)
df1162["awc"] = df1162.apply(awc, axis=1)
df1162["lime_LCC"]= df1162.apply(lime_LCC, axis=1)

df1163["erosion_risk_LCC"] = df1163.apply(erosion_risk_LCC, axis=1)
df1163["soil_tex_LCC"] = df1163.apply(soil_tex_LCC, axis=1)
df1163["perm_LCC"] = df1163.apply(perm_LCC, axis=1)
df1163["awc"] = df1163.apply(awc, axis=1)
df1163["lime_LCC"]= df1163.apply(lime_LCC, axis=1)

df1164["erosion_risk_LCC"] = df1164.apply(erosion_risk_LCC, axis=1)
df1164["soil_tex_LCC"] = df1164.apply(soil_tex_LCC, axis=1)
df1164["perm_LCC"] = df1164.apply(perm_LCC, axis=1)
df1164["awc"] = df1164.apply(awc, axis=1)
df1164["lime_LCC"]= df1164.apply(lime_LCC, axis=1)

df1165["erosion_risk_LCC"] = df1165.apply(erosion_risk_LCC, axis=1)
df1165["soil_tex_LCC"] = df1165.apply(soil_tex_LCC, axis=1)
df1165["perm_LCC"] = df1165.apply(perm_LCC, axis=1)
df1165["awc"] = df1165.apply(awc, axis=1)
df1165["lime_LCC"]= df1165.apply(lime_LCC, axis=1)

df1166["erosion_risk_LCC"] = df1166.apply(erosion_risk_LCC, axis=1)
df1166["soil_tex_LCC"] = df1166.apply(soil_tex_LCC, axis=1)
df1166["perm_LCC"] = df1166.apply(perm_LCC, axis=1)
df1166["awc"] = df1166.apply(awc, axis=1)
df1166["lime_LCC"]= df1166.apply(lime_LCC, axis=1)

# %%
# function to calculate overall LCC 
# input one row of the dataframe, to be applied to the full dataframe
def calc_LCC(row):
    lcc_final = max(row["erosion_risk_LCC"], row["soil_tex_LCC"], row["lime_LCC"], row["perm_LCC"])
    
    return lcc_final

# function to calculate topsoil LCC 
# input one row of the dataframe, to be applied to the full dataframe
def calc_LCC_top(row):
    lcc_final = max(row["LCC_final1"], row["LCC_final2"], row["LCC_final3"], row["LCC_final4"], row['awc_LCC_final'])
    
    return lcc_final

# function to calculate subsoil LCC 
# input one row of the dataframe, to be applied to the full dataframe
def calc_LCC_sub(row):
    lcc_final = max(row["LCC_final5"], row["LCC_final6"], row['awc_LCC_final'])
    
    return lcc_final

# %%
def limitation_T(row):
    LCC_final = row['LCC_topsoil']
    erosion = [row['erosion_risk_LCC1'], row['erosion_risk_LCC2'], row['erosion_risk_LCC3'],row['erosion_risk_LCC4']]
    tex = [row['soil_tex_LCC1'], row['soil_tex_LCC2'], row['soil_tex_LCC3'], row['soil_tex_LCC4']]
    perm = [row['perm_LCC1'], row['perm_LCC2'], row['perm_LCC3'], row['perm_LCC4']]
    awc = row['awc_LCC_final']
    lime = [row['lime_LCC1'], row['lime_LCC2'], row['lime_LCC3'], row['lime_LCC4']]

    
    lim = str(LCC_final)
    if LCC_final in erosion: 
        lim += "e"
    if LCC_final in tex: 
        lim +="s-t"
    if LCC_final in perm: 
        lim +="w-p"
    if awc == LCC_final: 
        lim +="s-a"
    if LCC_final in lime: 
        lim +="s-l"
    
    return(lim)

def limitation_S(row):
    LCC_final = row['LCC_subsoil']
    erosion = [row['erosion_risk_LCC5'], row['erosion_risk_LCC6']]
    tex = [row['soil_tex_LCC5'], row['soil_tex_LCC6']]
    perm = [row['perm_LCC5'], row['perm_LCC6']]
    awc = row['awc_LCC_final']
    lime = [row['lime_LCC5'], row['lime_LCC6']]

    
    lim = str(LCC_final)
    if LCC_final in erosion: 
        lim += "e"
    if LCC_final in tex: 
        lim +="s-t"
    if LCC_final in perm: 
        lim +="w-p"
    if awc == LCC_final: 
        lim +="s-a"
    if LCC_final in lime: 
        lim +="s-l"
    
    return(lim)

# %%
df01["LCC_final"] = df01.apply(calc_LCC, axis=1)
df691["LCC_final"] = df691.apply(calc_LCC, axis=1)
df1161["LCC_final"] = df1161.apply(calc_LCC, axis=1)
df02["LCC_final"] = df02.apply(calc_LCC, axis=1)
df692["LCC_final"] = df692.apply(calc_LCC, axis=1)
df1162["LCC_final"] = df1162.apply(calc_LCC, axis=1)
df03["LCC_final"] = df03.apply(calc_LCC, axis=1)
df693["LCC_final"] = df693.apply(calc_LCC, axis=1)
df1163["LCC_final"] = df1163.apply(calc_LCC, axis=1)
df04["LCC_final"] = df04.apply(calc_LCC, axis=1)
df694["LCC_final"] = df694.apply(calc_LCC, axis=1)
df1164["LCC_final"] = df1164.apply(calc_LCC, axis=1)
df05["LCC_final"] = df05.apply(calc_LCC, axis=1)
df695["LCC_final"] = df695.apply(calc_LCC, axis=1)
df1165["LCC_final"] = df1165.apply(calc_LCC, axis=1)
df06["LCC_final"] = df06.apply(calc_LCC, axis=1)
df696["LCC_final"] = df696.apply(calc_LCC, axis=1)
df1166["LCC_final"] = df1166.apply(calc_LCC, axis=1)

# %%
#calculating AWC value by adding all of the horizons 
df01["awc"] = df01["awc"]*1
df691["awc"] = df691["awc"]*1
df1161["awc"] = df1161["awc"]*1
df02["awc"] = df02["awc"]*5
df692["awc"] = df692["awc"]*5
df1162["awc"] = df1162["awc"]*5
df03["awc"] = df03["awc"]*10
df693["awc"] = df693["awc"]*10
df1163["awc"] = df1163["awc"]*10
df04["awc"] = df04["awc"]*15
df694["awc"] = df694["awc"]*15
df1164["awc"] = df1164["awc"]*15
df05["awc"] = df05["awc"]*30
df695["awc"] = df695["awc"]*30
df1165["awc"] = df1165["awc"]*30
df06["awc"] = df06["awc"]*40
df696["awc"] = df696["awc"]*40
df1166["awc"] = df1166["awc"]*40

# %%
df01 = df01.rename(columns={'bulk_dens': "bulk_dens1", 'cec': 'cec1', 'clay': 'clay1', 'course_fra': 'course_fra1',
       'silt': 'silt1', 'sand': 'sand1', 'ph': 'ph1', 'org_c_cont': 'org_c_cont1', 'prob_class': 'prob_class1', 'texture': 'texture1',
       'erosion_risk_LCC': 'erosion_risk_LCC1', 'soil_tex_LCC': 'soil_tex_LCC1', 'perm_LCC': 'perm_LCC1', 'awc': 'awc1', 'lime_LCC': 'lime_LCC1',
       'LCC_final': 'LCC_final1', 'limitation': 'limitation1'})
df691 = df691.rename(columns={'bulk_dens': "bulk_dens1", 'cec': 'cec1', 'clay': 'clay1', 'course_fra': 'course_fra1',
       'silt': 'silt1', 'sand': 'sand1', 'ph': 'ph1', 'org_c_cont': 'org_c_cont1', 'prob_class': 'prob_class1', 'texture': 'texture1',
       'erosion_risk_LCC': 'erosion_risk_LCC1', 'soil_tex_LCC': 'soil_tex_LCC1', 'perm_LCC': 'perm_LCC1', 'awc': 'awc1', 'lime_LCC': 'lime_LCC1',
       'LCC_final': 'LCC_final1', 'limitation': 'limitation1'})
df1161 = df1161.rename(columns={'bulk_dens': "bulk_dens1", 'cec': 'cec1', 'clay': 'clay1', 'course_fra': 'course_fra1',
       'silt': 'silt1', 'sand': 'sand1', 'ph': 'ph1', 'org_c_cont': 'org_c_cont1', 'prob_class': 'prob_class1', 'texture': 'texture1',
       'erosion_risk_LCC': 'erosion_risk_LCC1', 'soil_tex_LCC': 'soil_tex_LCC1', 'perm_LCC': 'perm_LCC1', 'awc': 'awc1', 'lime_LCC': 'lime_LCC1',
       'LCC_final': 'LCC_final1', 'limitation': 'limitation1'})
df02 = df02.rename(columns={'bulk_dens': "bulk_dens2", 'cec': 'cec2', 'clay': 'clay2', 'course_fra': 'course_fra2',
       'silt': 'silt2', 'sand': 'sand2', 'ph': 'ph2', 'org_c_cont': 'org_c_cont2', 'prob_class': 'prob_class2', 'texture': 'texture2',
       'erosion_risk_LCC': 'erosion_risk_LCC2', 'soil_tex_LCC': 'soil_tex_LCC2', 'perm_LCC': 'perm_LCC2', 'awc': 'awc2', 'lime_LCC': 'lime_LCC2',
       'LCC_final': 'LCC_final2', 'limitation': 'limitation2'})
df692 = df692.rename(columns={'bulk_dens': "bulk_dens2", 'cec': 'cec2', 'clay': 'clay2', 'course_fra': 'course_fra2',
       'silt': 'silt2', 'sand': 'sand2', 'ph': 'ph2', 'org_c_cont': 'org_c_cont2', 'prob_class': 'prob_class2', 'texture': 'texture2',
       'erosion_risk_LCC': 'erosion_risk_LCC2', 'soil_tex_LCC': 'soil_tex_LCC2', 'perm_LCC': 'perm_LCC2', 'awc': 'awc2', 'lime_LCC': 'lime_LCC2',
       'LCC_final': 'LCC_final2', 'limitation': 'limitation2'})
df1162 = df1162.rename(columns={'bulk_dens': "bulk_dens2", 'cec': 'cec2', 'clay': 'clay2', 'course_fra': 'course_fra2',
       'silt': 'silt2', 'sand': 'sand2', 'ph': 'ph2', 'org_c_cont': 'org_c_cont2', 'prob_class': 'prob_class2', 'texture': 'texture2',
       'erosion_risk_LCC': 'erosion_risk_LCC2', 'soil_tex_LCC': 'soil_tex_LCC2', 'perm_LCC': 'perm_LCC2', 'awc': 'awc2', 'lime_LCC': 'lime_LCC2',
       'LCC_final': 'LCC_final2', 'limitation': 'limitation2'})
df03 = df03.rename(columns={'bulk_dens': "bulk_dens3", 'cec': 'cec3', 'clay': 'clay3', 'course_fra': 'course_fra3',
       'silt': 'silt3', 'sand': 'sand3', 'ph': 'ph3', 'org_c_cont': 'org_c_cont3', 'prob_class': 'prob_class3', 'texture': 'texture3',
       'erosion_risk_LCC': 'erosion_risk_LCC3', 'soil_tex_LCC': 'soil_tex_LCC3', 'perm_LCC': 'perm_LCC3', 'awc': 'awc3', 'lime_LCC': 'lime_LCC3',
       'LCC_final': 'LCC_final3', 'limitation': 'limitation3'})
df693 = df693.rename(columns={'bulk_dens': "bulk_dens3", 'cec': 'cec3', 'clay': 'clay3', 'course_fra': 'course_fra3',
       'silt': 'silt3', 'sand': 'sand3', 'ph': 'ph3', 'org_c_cont': 'org_c_cont3', 'prob_class': 'prob_class3', 'texture': 'texture3',
       'erosion_risk_LCC': 'erosion_risk_LCC3', 'soil_tex_LCC': 'soil_tex_LCC3', 'perm_LCC': 'perm_LCC3', 'awc': 'awc3', 'lime_LCC': 'lime_LCC3',
       'LCC_final': 'LCC_final3', 'limitation': 'limitation3'})
df1163 = df1163.rename(columns={'bulk_dens': "bulk_dens3", 'cec': 'cec3', 'clay': 'clay3', 'course_fra': 'course_fra3',
       'silt': 'silt3', 'sand': 'sand3', 'ph': 'ph3', 'org_c_cont': 'org_c_cont3', 'prob_class': 'prob_class3', 'texture': 'texture3',
       'erosion_risk_LCC': 'erosion_risk_LCC3', 'soil_tex_LCC': 'soil_tex_LCC3', 'perm_LCC': 'perm_LCC3', 'awc': 'awc3', 'lime_LCC': 'lime_LCC3',
       'LCC_final': 'LCC_final3', 'limitation': 'limitation3'})
df04 = df04.rename(columns={'bulk_dens': "bulk_dens4", 'cec': 'cec4', 'clay': 'clay4', 'course_fra': 'course_fra4',
       'silt': 'silt4', 'sand': 'sand4', 'ph': 'ph4', 'org_c_cont': 'org_c_cont4', 'prob_class': 'prob_class4', 'texture': 'texture4',
       'erosion_risk_LCC': 'erosion_risk_LCC4', 'soil_tex_LCC': 'soil_tex_LCC4', 'perm_LCC': 'perm_LCC4', 'awc': 'awc4', 'lime_LCC': 'lime_LCC4',
       'LCC_final': 'LCC_final4', 'limitation': 'limitation4'})
df694 = df694.rename(columns={'bulk_dens': "bulk_dens4", 'cec': 'cec4', 'clay': 'clay4', 'course_fra': 'course_fra4',
       'silt': 'silt4', 'sand': 'sand4', 'ph': 'ph4', 'org_c_cont': 'org_c_cont4', 'prob_class': 'prob_class4', 'texture': 'texture4',
       'erosion_risk_LCC': 'erosion_risk_LCC4', 'soil_tex_LCC': 'soil_tex_LCC4', 'perm_LCC': 'perm_LCC4', 'awc': 'awc4', 'lime_LCC': 'lime_LCC4',
       'LCC_final': 'LCC_final4', 'limitation': 'limitation4'})
df1164 = df1164.rename(columns={'bulk_dens': "bulk_dens4", 'cec': 'cec4', 'clay': 'clay4', 'course_fra': 'course_fra4',
       'silt': 'silt4', 'sand': 'sand4', 'ph': 'ph4', 'org_c_cont': 'org_c_cont4', 'prob_class': 'prob_class4', 'texture': 'texture4',
       'erosion_risk_LCC': 'erosion_risk_LCC4', 'soil_tex_LCC': 'soil_tex_LCC4', 'perm_LCC': 'perm_LCC4', 'awc': 'awc4', 'lime_LCC': 'lime_LCC4',
       'LCC_final': 'LCC_final4', 'limitation': 'limitation4'})
df05 = df05.rename(columns={'bulk_dens': "bulk_dens5", 'cec': 'cec5', 'clay': 'clay5', 'course_fra': 'course_fra5',
       'silt': 'silt5', 'sand': 'sand5', 'ph': 'ph5', 'org_c_cont': 'org_c_cont5', 'prob_class': 'prob_class5', 'texture': 'texture5',
       'erosion_risk_LCC': 'erosion_risk_LCC5', 'soil_tex_LCC': 'soil_tex_LCC5', 'perm_LCC': 'perm_LCC5', 'awc': 'awc5', 'lime_LCC': 'lime_LCC5',
       'LCC_final': 'LCC_final5', 'limitation': 'limitation5'})
df695 = df695.rename(columns={'bulk_dens': "bulk_dens5", 'cec': 'cec5', 'clay': 'clay5', 'course_fra': 'course_fra5',
       'silt': 'silt5', 'sand': 'sand5', 'ph': 'ph5', 'org_c_cont': 'org_c_cont5', 'prob_class': 'prob_class5', 'texture': 'texture5',
       'erosion_risk_LCC': 'erosion_risk_LCC5', 'soil_tex_LCC': 'soil_tex_LCC5', 'perm_LCC': 'perm_LCC5', 'awc': 'awc5', 'lime_LCC': 'lime_LCC5',
       'LCC_final': 'LCC_final5', 'limitation': 'limitation5'})
df1165 = df1165.rename(columns={'bulk_dens': "bulk_dens5", 'cec': 'cec5', 'clay': 'clay5', 'course_fra': 'course_fra5',
       'silt': 'silt5', 'sand': 'sand5', 'ph': 'ph5', 'org_c_cont': 'org_c_cont5', 'prob_class': 'prob_class5', 'texture': 'texture5',
       'erosion_risk_LCC': 'erosion_risk_LCC5', 'soil_tex_LCC': 'soil_tex_LCC5', 'perm_LCC': 'perm_LCC5', 'awc': 'awc5', 'lime_LCC': 'lime_LCC5',
       'LCC_final': 'LCC_final5', 'limitation': 'limitation5'})
df06 = df06.rename(columns={'bulk_dens': "bulk_dens6", 'cec': 'cec6', 'clay': 'clay6', 'course_fra': 'course_fra6',
       'silt': 'silt6', 'sand': 'sand6', 'ph': 'ph6', 'org_c_cont': 'org_c_cont6', 'prob_class': 'prob_class6', 'texture': 'texture6',
       'erosion_risk_LCC': 'erosion_risk_LCC6', 'soil_tex_LCC': 'soil_tex_LCC6', 'perm_LCC': 'perm_LCC6', 'awc': 'awc6', 'lime_LCC': 'lime_LCC6',
       'LCC_final': 'LCC_final6', 'limitation': 'limitation6'})
df696 = df696.rename(columns={'bulk_dens': "bulk_dens6", 'cec': 'cec6', 'clay': 'clay6', 'course_fra': 'course_fra6',
       'silt': 'silt6', 'sand': 'sand6', 'ph': 'ph6', 'org_c_cont': 'org_c_cont6', 'prob_class': 'prob_class6', 'texture': 'texture6',
       'erosion_risk_LCC': 'erosion_risk_LCC6', 'soil_tex_LCC': 'soil_tex_LCC6', 'perm_LCC': 'perm_LCC6', 'awc': 'awc6', 'lime_LCC': 'lime_LCC6',
       'LCC_final': 'LCC_final6', 'limitation': 'limitation6'})
df1166 = df1166.rename(columns={'bulk_dens': "bulk_dens6", 'cec': 'cec6', 'clay': 'clay6', 'course_fra': 'course_fra6',
       'silt': 'silt6', 'sand': 'sand6', 'ph': 'ph6', 'org_c_cont': 'org_c_cont6', 'prob_class': 'prob_class6', 'texture': 'texture6',
       'erosion_risk_LCC': 'erosion_risk_LCC6', 'soil_tex_LCC': 'soil_tex_LCC6', 'perm_LCC': 'perm_LCC6', 'awc': 'awc6', 'lime_LCC': 'lime_LCC6',
       'LCC_final': 'LCC_final6', 'limitation': 'limitation6'})

# %%
#combine all soil horizon into one dataframe
df0 = pd.concat([df01, df02, df03, df04, df05, df06], axis=1)
df69 = pd.concat([df691, df692, df693, df694, df695, df696], axis=1)
df116 = pd.concat([df1161, df1162, df1163, df1164, df1165, df1166], axis=1)

# %%
df0['awc_total'] = df0['awc1']+df0['awc2']+df0['awc3']+df0['awc4']+df0['awc5']+df0['awc6']
df69['awc_total'] = df69['awc1']+df69['awc2']+df69['awc3']+df69['awc4']+df69['awc5']+df69['awc6']
df116['awc_total'] = df116['awc1']+df116['awc2']+df116['awc3']+df116['awc4']+df116['awc5']+df116['awc6']
df0['awc_T'] = df0['awc1']+df0['awc2']+df0['awc3']+df0['awc4']
df69['awc_T'] = df69['awc1']+df69['awc2']+df69['awc3']+df69['awc4']
df116['awc_T'] = df116['awc1']+df116['awc2']+df116['awc3']+df116['awc4']
df0['awc_S'] = df0['awc5']+df0['awc6']
df69['awc_S'] = df69['awc5']+df69['awc6']
df116['awc_S'] = df116['awc5']+df116['awc6']

# %%
df0.columns
# Out:
# Index(['Join_Count', 'TARGET_FID', 'bulk_dens1', 'cec1', 'clay1',
#        'course_fra1', 'silt1', 'sand1', 'ph1', 'org_c_cont1',
#        ...
#        'texture6', 'erosion_risk_LCC6', 'soil_tex_LCC6', 'perm_LCC6', 'awc6',
#        'lime_LCC6', 'LCC_final6', 'awc_total', 'awc_T', 'awc_S'],
#       dtype='object', length=115)

# %%
#calculate final awc LCC value based on new total awc value for partition
df0["awc_LCC_final"] = df0.apply(LAWC_LCC, axis = 1)
df69["awc_LCC_final"] = df69.apply(LAWC_LCC, axis = 1)
df116["awc_LCC_final"] = df116.apply(LAWC_LCC, axis = 1)

# %%
#calculate LCC for "topsoil" and "subsoil" by taking maximum of layer within these categories
df0["LCC_topsoil"] = df0.apply(calc_LCC_top, axis = 1)
df69["LCC_topsoil"] = df69.apply(calc_LCC_top, axis = 1)
df116["LCC_topsoil"] = df116.apply(calc_LCC_top, axis = 1)
df0["LCC_subsoil"] = df0.apply(calc_LCC_sub, axis = 1)
df69["LCC_subsoil"] = df69.apply(calc_LCC_sub, axis = 1)
df116["LCC_subsoil"] = df116.apply(calc_LCC_sub, axis = 1)

# %%
df0.columns
# Out:
# Index(['Join_Count', 'TARGET_FID', 'bulk_dens1', 'cec1', 'clay1',
#        'course_fra1', 'silt1', 'sand1', 'ph1', 'org_c_cont1',
#        ...
#        'perm_LCC6', 'awc6', 'lime_LCC6', 'LCC_final6', 'awc_total', 'awc_T',
#        'awc_S', 'awc_LCC_final', 'LCC_topsoil', 'LCC_subsoil'],
#       dtype='object', length=118)

# %%
df0["T_limitation"] = df0.apply(limitation_T, axis=1)
df0["S_limitation"] = df0.apply(limitation_S, axis=1)
df69["T_limitation"] = df69.apply(limitation_T, axis=1)
df69["S_limitation"] = df69.apply(limitation_S, axis=1)
df116["T_limitation"] = df116.apply(limitation_T, axis=1)
df116["S_limitation"] = df116.apply(limitation_S, axis=1)

# %%
df0 = df0.loc[:,~df0.columns.duplicated()]
df69 = df69.loc[:,~df69.columns.duplicated()]
df116 = df116.loc[:,~df116.columns.duplicated()]

# %%
df0.columns[:20]
# Out:
# Index(['Join_Count', 'TARGET_FID', 'bulk_dens1', 'cec1', 'clay1',
#        'course_fra1', 'silt1', 'sand1', 'ph1', 'org_c_cont1', 'prob_class1',
#        'gridcode', 'texture1', 'erosion_risk_LCC1', 'soil_tex_LCC1',
#        'perm_LCC1', 'awc1', 'lime_LCC1', 'LCC_final1', 'bulk_dens2'],
#       dtype='object')

# %%
# calculate slope
df0['slope']=df0['gridcode']/10000
df69['slope']=df69['gridcode']/10000
df116['slope']=df116['gridcode']/10000
# Out:
# C:\Users\Research\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df0.to_csv("LCC_SG_dosso_0_fullresults")
df69.to_csv("LCC_SG_dosso_69_fullresults")
df116.to_csv("LCC_SG_dosso_116_fullresults")
